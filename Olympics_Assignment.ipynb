# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("summer.csv")

# %%
df.head(10)
# Out:
#    Year    City     Sport  ... Gender                       Event   Medal
# 0  1896  Athens  Aquatics  ...    Men              100M Freestyle    Gold
# 1  1896  Athens  Aquatics  ...    Men              100M Freestyle  Silver
# 2  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# 5  1896  Athens  Aquatics  ...    Men             1200M Freestyle  Bronze
# 6  1896  Athens  Aquatics  ...    Men             1200M Freestyle    Gold
# 7  1896  Athens  Aquatics  ...    Men             1200M Freestyle  Silver
# 8  1896  Athens  Aquatics  ...    Men              400M Freestyle  Bronze
# 9  1896  Athens  Aquatics  ...    Men              400M Freestyle    Gold
#
# [10 rows x 9 columns]

# %%
a=len(df["City"].unique())
print("Summer Olympics is held in",a,"cities" )
# Out:
# Summer Olympics is held in 22 cities

# %%
q2_I = df.loc[:,["Sport","Medal"]]
q2_I["G_C"]=np.where(q2_I["Medal"]=="Gold",True,False)
q2_II=q2_I.loc[:, ["Sport","G_C"]]
q2_II.head()
for ind, row in q2_II.iterrows():
    if row['G_C']==True:
        q2_II.loc[ind,"Y"]=row['Sport']
    else:
      pass
q2lst=[]
for i in q2_II['Y'].unique():
  q2lst.append((i,len(q2_II[q2_II["Y"]==i])))
q2lst 
q2_df=pd.DataFrame(q2lst, columns=["Sport","Gold"])
q2_df.sort_values(by="Gold", ascending=False).head()
# Out:
#          Sport  Gold
# 0     Aquatics  1421
# 2    Athletics  1215
# 18      Rowing   890
# 5   Gymnastics   820
# 4      Fencing   552

# %%
q6_I = df.loc[:,["Year","Country"]]

q6_I['M_I'] = np.where(q6_I['Country']== 'IND',df["Year"], False)
q6_I['C_I'] = np.where(q6_I['Country']== 'IND',"IND", False)

q6df=q6_I.loc[: ,["M_I","C_I"]]

minvalue_series = q6df.min(axis = 1)
minvalue_series

# %%
for ind, row in q6_I.iterrows():
    if row['Country']=="IND":
        q6_I.loc[ind,"Y"]=row['Year']
    else:
      pass
q6_I2=q6_I.loc[:,["Y","Year"]]
q6_I2["Y"].min(axis=0)
# Out:
# 1900

# %%
for ind, row in new_frame.iterrows():
    if row['Medal']=='Gold':
        df.loc[ind,"Gold Counter"]=1
    else:
        df.loc[ind,"Gold Counter"]=0

new_frame.head()
# Out:
#       Sport   Medal
# 0  Aquatics    Gold
# 1  Aquatics  Silver
# 2  Aquatics  Bronze
# 3  Aquatics    Gold
# 4  Aquatics  Silver

# %%
q2=[]
for i in df['Sport'].unique():
  q2.append((i,len(df[df["Sport"]==i])))
q3df=pd.DataFrame(q2, columns=["Sport","Medal"])
q3df.sort_values(by="Medal", ascending= False).head()
# Out:
#          Sport  Medal
# 0     Aquatics   4170
# 1    Athletics   3638
# 17      Rowing   2667
# 4   Gymnastics   2307
# 3      Fencing   1613

# %%
q4=[]
for i in df['Athlete'].unique():
  q4.append((i,len(df[df["Athlete"]==i])))
q4df=pd.DataFrame(q4, columns=["Athlete","Medal"])
q4df.sort_values(by="Medal", ascending= False).head()
# Out:
#                     Athlete  Medal
# 18640       PHELPS, Michael     22
# 7197       LATYNINA, Larisa     18
# 9948     ANDRIANOV, Nikolay     15
# 6591           ONO, Takashi     13
# 5103   MANGIAROTTI, Edoardo     13

# %%
q5= df.loc[:,["Athlete","Medal"]]
q5
q5l=[]
q5['Gold_Counter'] = np.where(q5['Medal']== 'Gold',True , False)
q5_1=q5.loc[:,["Athlete","Gold_Counter"]]

q5_1L=[]
for i in q5_1['Athlete'].unique():
  q5_1L.append((i,len(q5_1[q5_1["Athlete"]==i])))
q5_1L
# Out:
# [('HAJOS, Alfred', 2),
#  ('HERSCHMANN, Otto', 2),
#  ('DRIVAS, Dimitrios', 1),
#  ('MALOKINIS, Ioannis', 1),
#  ('CHASAPIS, Spiridon', 1),
#  ('CHOROPHAS, Efstathios', 2),
#  ('ANDREOU, Joannis', 1),
#  ('NEUMANN, Paul', 1),
#  ('PEPANOS, Antonios', 1),
#  ('LANE, Francis', 1),
#  ('SZOKOLYI, Alajos', 1),
#  ('BURKE, Thomas', 2),
#  ('HOFMANN, Fritz', 4),
#  ('CURTIS, Thomas', 1),
#  ('GOULDING, Grantley', 1),
#  ('LERMUSIAUX, Albin', 1),
#  ('FLACK, Edwin', 3),
#  ('BLAKE, Arthur', 1),
#  ('GMELIN, Charles', 1),
#  ('JAMISON, Herbert', 1),
#  ('GOLEMIS, Dimitrios', 1),
#  ('DANI, Nandor', 1),
#  ('VERSIS, Sotirios', 2),
#  ('GARRETT, Robert', 6),
#  ('PARASKEVOPOULOS, Panagiotis', 1),
#  ('CLARK, Ellery', 2),
#  ('CONNOLLY, James', 5),
#  ('KELLNER, Gyula', 1),
#  ('LOUIS, Spyridon', 1),
#  ('VASILAKOS, Kharilaos', 1),
#  ('DAMASKOS, Evangelos', 1),
#  ('THEODOROPOULOS, Ioannis', 1),
#  ('HOYT, William Welles', 1),
#  ('TYLER, Albert', 1),
#  ('PAPASIDERIS, Georgios', 1),
# ...

# %%
q5df=pd.DataFrame(q5_1L,columns=["Athlete","Gold"])
q5df.sort_values(by="Gold",ascending=False)
# Out:
#                      Athlete  Gold
# 18640        PHELPS, Michael    22
# 7197        LATYNINA, Larisa    18
# 9948      ANDRIANOV, Nikolay    15
# 6591            ONO, Takashi    13
# 5103    MANGIAROTTI, Edoardo    13
# ...                      ...   ...
# 8539             ZAKA, Uddin     1
# 8538            ZAFAR, Hayat     1
# 8534        MUHAMMAD, Rashid     1
# 8533   MANNA, Muhammad Afzal     1
# 22761         LIDBERG, Jimmy     1
#
# [22762 rows x 2 columns]
